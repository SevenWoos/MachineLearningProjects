# %% [markdown]
# # 1) Tokenization

# %% [markdown]
# * Tokenization = step in NLP, where we break up textual input into smaller units(tokens). Helps with improving interpretability of text by different models.
#   - Tokens can be in the form of:
#     - words
#     - characters
#     - sub-words
#     - sentences
#
# ![image.png](attachment:image.png)

# %% [markdown]
# * Tokens = words or sub-words in the contetx of NLP.
#   - EX: a word, or a character

# %% [markdown]
# * There are different types of tokenization based on how tetx is segmented.
#   - Word Tokenization
#
#   - Character Tokenization
#
#   - Subword Tokenization
#
#   - Sentence Tokenization
#
#   - N-gram Tokenization
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Word Tokenization
#
# * Word Tokenization = most commonly used method where text is divided into INDIVIDUAL WORDS.
#   - Works well for languages with clear word boundaries like English.
#
#   - EX:
#     - Input: ["Machine Learning is fascinating"]
#
#     - Output --> ["Machine", "learning", "is", "fascinating"]

# %% [markdown]
# ### Character Tokenization
#
# * Character Tokenization = textual data split and converted into sequence of INDIVDUAL CHARACTERS.
#   - Beneficial for tasks that require a detailed analysis like spelling correction.
#
#   - Good of modeling character-level language.
#
#   - EX:
#     - Input before tokenization: ["You are helpful"]
#
#     - Output when tokenized by characters: ["Y", "o", "u", " ", "a", "r", "e", " ", "h", "e", "l", "p", "f", "u", "l"]

# %% [markdown]
# ### Sub-word Tokenization
#
# * Sub-word Tokenization = breaks text into meaningful words/units. It is larger than a single character and smaller than a full word.
#   - useful for languages that form words by COMBINING SMALLER UNITS.
#
#   - EX: ["Time", "table"]
#         ["Rain", "coat"]
#         ["Grace", "fully"]
#         ["Run", "way"]

# %% [markdown]
# ### Sentence Tokenization
#
# * Sentence Tokenization = dividing paragraphs or large sets of sentences into separated sentences as tokens.
#   - Useful for sentence analysis or processing.
#
#   - EX:
#     - Input before tokenization: ["Artificial Intelligence is an emerging technology. Machine learning is fascinating. Computer Vision handles images. "]
#
#     - Output when tokenized by sentences ["Artificial Intelligence is an emerging technology.", "Machine learning is fascinating.", "Computer Vision handles images."]

# %% [markdown]
# ### N-gram Tokenization
#
# * N-gram Tokenization = splits words into FIXED-SIZED chunks(size = n) of data.
#   - EX:
#       - Input before tokenization: ["Machine learning is powerful"]
#
#       - Output when tokenized by bigrams: [('Machine', 'learning'), ('learning', 'is'), ('is', 'powerful')]

# %% [markdown]
# * Need to install Python 3.12, not 3.12.14(new) to install Tensorflow.
#
# * Deactivate current environment
#   - deactivate
#   - conda deactivate
#
# * Install python 3.12
#   - python3.12 --version
#
# * Create a new vitural environment.
#   - python3.12 -m venv venv-tf
#   - source venv-tf/bin/activate
#   - python --version
#
# * Install tensorflow
#   - python -m pip install --upgrade pip
#   - python -m pip install tensorflow

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.text import Tokenizer

# %% [markdown]
# ## Implementation for Tokenization
#
# * Sentence Tokenization using sent_tokenize

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/svenwu/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import sent_tokenize

# %%
text = "Hello everyone. Welcome to GeeksforGeeks. You are studying NLP article."
sent_tokenize(text)
# Out:
# ['Hello everyone.',
#  'Welcome to GeeksforGeeks.',
#  'You are studying NLP article.']

# %% [markdown]
# ### Sentence Tokenization using PunktSentenceTokenizer
#
# * It is efficient to use 'PunktSentenceTokenizer' to from the NLTK library. The Punkt tokenizer is a data-driven sentence tokenizer that comes with NLTK. It is trained on large corpus of text to identify sentence boundaries.

# %%
# Loading PunktSentenceTokenizer using English pickle file
tokenizer = nltk.data.load('tokenizers/punkt/PY3/english.pickle')
tokenizer.tokenize(text)
# Out:
# ['Hello everyone.',
#  'Welcome to GeeksforGeeks.',
#  'You are studying NLP article.']

# %% [markdown]
# ### Tokenize sentence of different language
#
# * Sentences from different languages can also be tokenized using a different pickle file other than English.

# %%
# import nltk.data

spanish_tokenizer = nltk.data.load('tokenizers/punkt/PY3/spanish.pickle')

text = 'Hola amigo. Estoy bien.'
spanish_tokenizer.tokenize(text)
# Out:
# ['Hola amigo.', 'Estoy bien.']

# %% [markdown]
# ### Word Tokenization using work_tokenize
#
# * The word_tokenize function is helpful for breaking down a sentence or text into its constituent words.

# %%
from nltk.tokenize import word_tokenize

text = "Hello everyone. Welcome to GeeksforGeeks."
word_tokenize(text)
# Out:
# ['Hello', 'everyone', '.', 'Welcome', 'to', 'GeeksforGeeks', '.']

# %% [markdown]
# ### Word Tokenization Using TreebankWordTokenizer
#
# * The code snippet uses the TreebankWordTokenizer from the Natural Language Toolkit (NLTK) to tokenize a given text into individual words.

# %%
from nltk.tokenize import TreebankWordTokenizer

tokenizer = TreebankWordTokenizer()
tokenizer.tokenize(text)
# Out:
# ['Hello', 'everyone.', 'Welcome', 'to', 'GeeksforGeeks', '.']

# %% [markdown]
# ### Word Tokenization using WordPunctTokenizer
#
# * The WordPunctTokenizer is one of the NLTK tokenizers that splits words based on PUNCTUATION boundaries. Each punctuation mark is treated as a separate token.

# %%
from nltk.tokenize import WordPunctTokenizer

tokenizer = WordPunctTokenizer()
tokenizer.tokenize("Let's see how it's working.")
# Out:
# ['Let', "'", 's', 'see', 'how', 'it', "'", 's', 'working', '.']

# %% [markdown]
# ### Word Tokenization using Regular Expression
#
# * The code snippet uses the RegexpTokenizer from the Natural Language Toolkit (NLTK) to tokenize a given text based on a regular expression pattern.
#
# * Using regular expressions allows for more fine-grained control over tokenization and you can customize the pattern based on your specific requirements.

# %%
from nltk.tokenize import RegexpTokenizer

tokenizer = RegexpTokenizer(r'\w+')
text = "Let's see how it's working."
tokenizer.tokenize(text)
# Out:
# ['Let', 's', 'see', 'how', 'it', 's', 'working']

# %% [markdown]
# ### More Techniques for Tokenization
#
# * Spacy: Spacy is NLP library that provide robust tokenization capabilities.
#
# * BERT tokenizer: BERT uses Word Piece tokenizer, which is a type of sub-word tokenizer for tokenizing input text. Using regular expressions allows for more fine-grained control over tokenization and you can customize the pattern based on your specific requirements.
#
# * Byte-Pair Encoding: Byte Pair Encoding (BPE) is a data compression algorithm that has also found applications in the field of NLP, specifically for tokenization. It is a Sub-word Tokenization technique that works by iteratively merging the most frequent pairs of consecutive bytes (or characters) in a given corpus.
#
# * Sentence Piece: Sentence Piece is another sub-word tokenization algorithm commonly used for NLP tasks. It is designed to be language-agnostic and works by iteratively merging frequent sequences of characters or sub words in a given corpus.

# %% [markdown]
# ### Limitations
#
# * Languages like Chinese and Japanese do NOT use clear word boundaries, making tokenization challenging. In contrast, Arabic uses spaces, but its rich morphology and word variations still make tokenization complex.
#
# * Tokenizing text that may include more than one word
#   - For example: email addresses, URLs and special symbols
