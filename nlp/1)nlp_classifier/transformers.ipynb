# %% [markdown]
# # Transformers

# %% [markdown]
# ## Attention
#
# * RNNs have drawbacks.
#
# * Use Atttention!
#   - We can feed in a phrase, and as we iterate through the tokens in that phrase, we can identify which tokens are RELEVANT and should be ATTENDED to.
#
#   - Feeds in words at SAME TIME, using positional encoding.
#
#   - EX: "I need to go to the bank and write a check."
#
#     - When we get to the word "check", it will have decided that "write" and "bank" as RELEVANT words.
#
#     - "At "go", "bank" might be a relevant word
#
# * Our network learns to figure out what is IMPORTANT AND RELEVANT given certain tokens.
#   - The network LEARNS to ask questions about phrases it sees, to learn how tokens relate.

# %% [markdown]
# ## Transformer Architecture
#
# * OpenAI GPT architecture is forward-nature.
#   - It is trained on language modelling.
#
#   - Given some words, what are the next words coming after?

# %% [markdown]
# ## Bert Transformer Architecture
#
# * Bert in Python

# %% [markdown]
# * Bert = bidirectional Transformer architecture.
#   - Bidirectional nature lets it capture a lot on language.

# %%
# !pip install spacy transformers
# !python -m spacy download en_trf_bertbaseduncased_lg
# !python -m spacy download en_core_web_trf
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 457.4/457.4 MB 3.0 MB/s  0:02:290:00:0100:04
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 688.6/688.6 kB 3.1 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [en-core-web-trf] [en-core-web-trf]
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_trf')

# %%
import spacy
import numpy as np
import torch

# %%
# We will NOT be training the Bert model. They are very massive, so we will just import.
# en_core_web_trf is a spaCy English NLP pipeline based on the pretrained roberta-base transformer model. RoBERTa is a BERT-derived Transformer encoder model.

# We can fine-tune as we see fit for our specific task.
# nlp = spacy.load("en_core_web_trf")
nlp = spacy.load("en_core_web_md")

# %%
doc = nlp("Here is simple text to encode")

# %%
class Category:
  BOOKS = 'BOOKS'
  BANK = 'BANK'

# %%
train_x = ["good characters and plot progression", "check out the book", "good story. would recommend", "novel recommendation", "need to make a deposit to the bank", "ibalance inquiry savings", "save money"]
train_y = [Category.BOOKS, Category.BOOKS, Category.BOOKS, Category.BOOKS, Category.BANK, Category.BANK, Category.BANK]

# %%
from sklearn import svm

# %%
# We now have a NEW MODEL for our  NLP Engine, as opposed to the word vectors we were using earlier.
docs = [nlp(text) for text in train_x]
train_x_vectors = [doc.vector for doc in docs]

clf_svm = svm.SVC(kernel="linear")

clf_svm.fit(train_x_vectors, train_y)
# Out:
# SVC(kernel='linear')

# %%
test_x = ["book"]
docs = [nlp(text) for text in test_x]
test_x_vectors = [doc.vector for doc in docs]

clf_svm.predict(test_x_vectors)
# Out:
# array(['BOOKS'], dtype='<U5')

# %%
# The word "check" only appears in our "books" category, none in the "bank" category, but it WORKS!
# When we say "I need to write a check", it knows that we mean "banking"
test_x = ["i need to write a check"]
docs = [nlp(text) for text in test_x]
test_x_vectors = [doc.vector for doc in docs]

clf_svm.predict(test_x_vectors)
# Out:
# array(['BANK'], dtype='<U5')

# %%
test_x = ["check this story out"]
docs = [nlp(text) for text in test_x]
test_x_vectors = [doc.vector for doc in docs]

clf_svm.predict(test_x_vectors)
# Out:
# array(['BOOKS'], dtype='<U5')

# %% [markdown]
# * Can finetune our transformer model!
#
# * Look into HuggingFace's Transformers, to build off our current model.
