# %% [markdown]
# # Built-in PyTorch Transformer — StatQuest Example
#
# This mirrors the small English → Spanish example from StatQuest, but uses PyTorch’s built-in `nn.Transformer` for the Transformer internals.

# %% [markdown]
# ## 1. Vocabulary
#
# Each word/token is assigned an integer ID.

# %%
import torch
import torch.nn as nn
import lightning as L


# ============================================================
# VOCABULARIES
# ============================================================

# Input vocabulary (English)
input_vocab = {
    '<SOS>': 0,   # Start of sequence
    'lets': 1,
    'to': 2,
    'go': 3
}

# Output vocabulary (Spanish)
output_vocab = {
    '<SOS>': 0,   # Start of sequence
    'ir': 1,
    'vamos': 2,
    'y': 3,
    '<EOS>': 4    # End of sequence
}

# %% [markdown]
# ## 2. Input Words and Labels
#
# StatQuest’s original word IDs are kept here. The model will prepend `<SOS>` to the input and decoder sequences.

# %%
# English phrases:
# ["lets go", "to go"]
inputs = torch.tensor([
    [1, 3],
    [2, 3]
])

# Spanish translations:
# ["vamos", "ir"]
labels = torch.tensor([
    [2],
    [1]
])

# %% [markdown]
# ## 3. Positional Encoding
#
# A Transformer needs information about token order. Word embeddings tell the model **what** the tokens are; positional encoding tells it **where** they occur in the sequence.

# %%
class PositionalEncoding(nn.Module):

    def __init__(self, d_model, max_len=5000):
        super().__init__()

        # Create a positional encoding matrix.
        # Shape: (max_len, d_model)
        position = torch.arange(max_len).unsqueeze(1)

        # Frequencies used for the sine/cosine pattern.
        div_term = torch.exp(
            torch.arange(0, d_model, 2) *
            (-torch.log(torch.tensor(10000.0)) / d_model)
        )

        pe = torch.zeros(max_len, d_model)

        # Even dimensions use sine.
        pe[:, 0::2] = torch.sin(position * div_term)

        # Odd dimensions use cosine.
        pe[:, 1::2] = torch.cos(position * div_term)

        # Shape becomes (1, max_len, d_model) so it can be
        # added to a batch of embeddings.
        pe = pe.unsqueeze(0)

        # Store as a buffer rather than a trainable parameter.
        self.register_buffer('pe', pe)

    def forward(self, x):
        # Add positional information to the word embeddings.
        return x + self.pe[:, :x.size(1)]

# %% [markdown]
# ## 4. Transformer Model
#
# We build the **embeddings, positional encoding, and final output layer** ourselves.
#
# The actual Transformer architecture is provided by PyTorch’s built-in `nn.Transformer`.

# %%
class TransformerModel(L.LightningModule):

    def __init__(self):
        super().__init__()

        # ====================================================
        # EMBEDDING DIMENSION
        # ====================================================
        # Every token will become a vector with 4 values.
        self.d_model = 4

        # ====================================================
        # 1. INPUT WORD EMBEDDING
        # ====================================================
        # English token IDs -> 4-dimensional embedding vectors.
        self.input_embedding = nn.Embedding(
            num_embeddings=len(input_vocab),
            embedding_dim=self.d_model
        )

        # ====================================================
        # 2. OUTPUT WORD EMBEDDING
        # ====================================================
        # Spanish token IDs -> 4-dimensional embedding vectors.
        self.output_embedding = nn.Embedding(
            num_embeddings=len(output_vocab),
            embedding_dim=self.d_model
        )

        # ====================================================
        # 3. POSITIONAL ENCODING
        # ====================================================
        # Adds information about the position of each token.
        self.input_positional_encoding = PositionalEncoding(self.d_model)
        self.output_positional_encoding = PositionalEncoding(self.d_model)

        # ====================================================
        # 4. BUILT-IN PYTORCH TRANSFORMER
        # ====================================================
        self.transformer = nn.Transformer(
            d_model=self.d_model,
            nhead=2,
            num_encoder_layers=1,
            num_decoder_layers=1,
            batch_first=True
        )

        # IMPORTANT:
        # nn.Transformer handles the internal Transformer pieces:
        #
        # ENCODER
        #   - Self-Attention
        #   - Feed-Forward Neural Network
        #   - Residual Connections
        #   - Layer Normalization
        #
        # DECODER
        #   - Masked Self-Attention
        #   - Encoder-Decoder / Cross-Attention
        #   - Feed-Forward Neural Network
        #   - Residual Connections
        #   - Layer Normalization
        #
        # nhead=2 -> 2 attention heads
        # num_encoder_layers=1 -> 1 encoder layer
        # num_decoder_layers=1 -> 1 decoder layer

        # ====================================================
        # 5. FINAL LINEAR / OUTPUT PROJECTION
        # ====================================================
        # Transformer output: 4 values
        # Output vocabulary: 5 possible tokens
        #
        # Therefore, this maps:
        # 4-dimensional representation -> 5 vocabulary logits
        self.output_layer = nn.Linear(
            self.d_model,
            len(output_vocab)
        )

        # ====================================================
        # 6. LOSS FUNCTION
        # ====================================================
        self.loss = nn.CrossEntropyLoss()

# %% [markdown]
# ## 5. Forward Pass
#
# This follows the diagram: **Word Embedding → Positional Encoding → Encoder/Decoder Transformer → Linear Output**.

# %%
    def forward(self, inputs, labels):

        # ====================================================
        # ENCODER SIDE
        # ====================================================

        # ----------------------------------------------------
        # 1. PREPEND <SOS> TO THE ENGLISH INPUT
        # ----------------------------------------------------
        # Original:
        # [lets, go]
        # [to,   go]
        #
        # Becomes:
        # [<SOS>, lets, go]
        # [<SOS>, to,   go]
        sos_input = torch.full(
            (inputs.size(0), 1),
            input_vocab['<SOS>'],
            dtype=inputs.dtype,
            device=inputs.device
        )

        encoder_input = torch.cat(
            (sos_input, inputs),
            dim=1
        )

        # ----------------------------------------------------
        # 2. INPUT WORD EMBEDDING
        # ----------------------------------------------------
        input_embeddings = self.input_embedding(encoder_input)

        # ----------------------------------------------------
        # 3. INPUT POSITIONAL ENCODING
        # ----------------------------------------------------
        input_embeddings = self.input_positional_encoding(
            input_embeddings
        )

        # ====================================================
        # DECODER SIDE
        # ====================================================

        # ----------------------------------------------------
        # 4. PREPEND <SOS> TO THE SPANISH DECODER INPUT
        # ----------------------------------------------------
        # Labels:
        # [vamos]
        # [ir]
        #
        # Decoder input becomes:
        # [<SOS>, vamos]
        # [<SOS>, ir]
        sos_output = torch.full(
            (labels.size(0), 1),
            output_vocab['<SOS>'],
            dtype=labels.dtype,
            device=labels.device
        )

        decoder_input = torch.cat(
            (sos_output, labels),
            dim=1
        )

        # ----------------------------------------------------
        # 5. OUTPUT WORD EMBEDDING
        # ----------------------------------------------------
        output_embeddings = self.output_embedding(decoder_input)

        # ----------------------------------------------------
        # 6. OUTPUT POSITIONAL ENCODING
        # ----------------------------------------------------
        output_embeddings = self.output_positional_encoding(
            output_embeddings
        )

        # ----------------------------------------------------
        # 7. DECODER CAUSAL MASK
        # ----------------------------------------------------
        # Prevent the decoder from looking at future tokens.
        # This gives us masked self-attention during training.
        tgt_mask = nn.Transformer.generate_square_subsequent_mask(
            decoder_input.size(1)
        ).to(labels.device)

        # ====================================================
        # 8. BUILT-IN TRANSFORMER
        # ====================================================
        transformer_output = self.transformer(
            src=input_embeddings,
            tgt=output_embeddings,
            tgt_mask=tgt_mask
        )

        # Inside this one call, PyTorch performs:
        #
        # Encoder:
        #   Self-Attention
        #        ↓
        #   Feed-Forward Network
        #
        # Decoder:
        #   Masked Self-Attention
        #        ↓
        #   Encoder-Decoder / Cross-Attention
        #        ↓
        #   Feed-Forward Network
        #
        # Residual connections and layer normalization are also
        # handled internally by nn.Transformer.

        # ====================================================
        # 9. FINAL LINEAR OUTPUT LAYER
        # ====================================================
        logits = self.output_layer(transformer_output)

        return logits

# %% [markdown]
# ## 6. Training Step
#
# The decoder receives `<SOS>` plus the previous target token and learns to predict the next token.

# %%
    def training_step(self, batch, batch_idx):

        inputs, labels = batch

        # ----------------------------------------------------
        # Get model predictions.
        # ----------------------------------------------------
        logits = self(inputs, labels)

        # ----------------------------------------------------
        # TARGET OUTPUT
        # ----------------------------------------------------
        # Decoder input:
        # [<SOS>, vamos]
        # [<SOS>, ir]
        #
        # Desired target:
        # [vamos, <EOS>]
        # [ir,    <EOS>]
        eos = torch.full(
            (labels.size(0), 1),
            output_vocab['<EOS>'],
            dtype=labels.dtype,
            device=labels.device
        )

        target = torch.cat(
            (labels, eos),
            dim=1
        )

        # ----------------------------------------------------
        # CROSS-ENTROPY LOSS
        # ----------------------------------------------------
        # CrossEntropyLoss expects:
        # predictions -> (number of tokens, vocabulary size)
        # targets     -> (number of tokens)
        loss = self.loss(
            logits.reshape(-1, len(output_vocab)),
            target.reshape(-1)
        )

        self.log('train_loss', loss)

        return loss

    # ========================================================
    # OPTIMIZER
    # ========================================================
    def configure_optimizers(self):

        return torch.optim.Adam(
            self.parameters(),
            lr=0.01
        )

# %% [markdown]
# ## 7. DataLoader

# %%
dataset = torch.utils.data.TensorDataset(
    inputs,
    labels
)

dataloader = torch.utils.data.DataLoader(
    dataset,
    batch_size=2,
    shuffle=False
)

# %% [markdown]
# ## 8. Train the Model

# %%
transformer = TransformerModel()

trainer = L.Trainer(
    max_epochs=30
)

trainer.fit(
    transformer,
    train_dataloaders=dataloader
)

# %% [markdown]
# ## Architecture Summary
#
# **What we build ourselves:**
# - Input word embedding
# - Output word embedding
# - Positional encoding
# - Final linear/output layer
# - Loss function
# - Training logic
#
# **What PyTorch builds for us inside `nn.Transformer`:**
# - Encoder self-attention
# - Decoder masked self-attention
# - Encoder-decoder (cross) attention
# - Feed-forward networks
# - Residual connections
# - Layer normalization
